# %%
import pandas as pd
data = pd.read_csv("C:/Users/MSI/OneDrive/Desktop/listings.csv")
data
# Out:
#                        id                                               name  \
# 0                   13188                  Garden level studio in ideal loc.
# 1                   13358                   Curated  Designer Downtown Suite
# 2                   13490                       Vancouver's best kept secret
# 3                   16254      Close to PNE/Hastings Park Garden level suite
# 4                   16611  1 block to skytrain station, shops,restaurant,...
# ...                   ...                                                ...
# 6206  1238078096894406182                         Cute Modern 1Br 1Bth Suite
# 6207  1238340291500401580                        Luxury Retreat in Vancouver
# 6208  1238368298136737525                    King Bedroom w Bath&Living Room
# 6209  1238641592691060888                          King Bed Private Bathroom
# 6210  1238720183096218523                    Cozy 2 bedroom 2 bathroom condo
#
# ...

# %%
# !pip install matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv("C:/Users/MSI/OneDrive/Desktop/listings.csv")

# Data Cleaning: Fill missing values for price and remove NaN rows in key columns
data['price'] = data['price'].fillna(0)
data.dropna(subset=['neighbourhood', 'price', 'latitude', 'longitude'], inplace=True)

# Group by neighborhood to calculate listings count and average price
neighborhood_summary = data.groupby('neighbourhood').agg(
    listings_count=('id', 'count'),
    avg_price=('price', 'mean')
).reset_index()

# Sort by listings count to identify high-concentration neighborhoods
neighborhood_summary = neighborhood_summary.sort_values(by='listings_count', ascending=False)

# Plotting: Bar chart for high-concentration neighborhoods and average pricing
plt.figure(figsize=(12, 6))
sns.barplot(
    x='listings_count',
    y='neighbourhood',
    data=neighborhood_summary.head(10),
    palette='viridis'
)
plt.title('Top 10 Neighborhoods by Listing Count')
plt.xlabel('Number of Listings')
plt.ylabel('Neighborhood')
plt.show()

# Scatter plot for average pricing trends
plt.figure(figsize=(12, 6))
sns.scatterplot(
    x='listings_count',
    y='avg_price',
    data=neighborhood_summary,
    hue='neighbourhood',
    legend=False,
    palette='tab10'
)
plt.title('Neighborhood Listings vs. Average Price')
plt.xlabel('Number of Listings')
plt.ylabel('Average Price (USD)')
plt.show()
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_19168\1093430586.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
Tôi tên là Minh
# Out:
#   Cell In[1], line 1
#     Tôi tên là Minh
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Tôi tên là Minh

# %% [markdown]
# ### Grading
# The final score that you will receive for your programming assignment is generated in relation to the total points set in your programming assignment item—not the total point value in the nbgrader notebook.<br>
# When calculating the final score shown to learners, the programming assignment takes the percentage of earned points vs. the total points provided by nbgrader and returns a score matching the equivalent percentage of the point value for the programming assignment. <br>
# **DO NOT CHANGE VARIABLE OR METHOD SIGNATURES** The autograder will not work properly if your change the variable or method signatures.
